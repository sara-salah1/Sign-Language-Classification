# %% [markdown]
# # ***Connect to Drive***

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# # **Python Libraries**

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import random
from sklearn.metrics import confusion_matrix
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
import tensorflow as tf
import tensorflow.keras
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, EarlyStopping, ReduceLROnPlateau
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, BatchNormalization, MaxPool2D, Flatten, Dense, Dropout
import warnings

sns.set()
# %matplotlib inline
warnings.filterwarnings("ignore")

# %%
plt.figure(figsize = (10,10))
img = plt.imread('/content/drive/MyDrive/amer_sign2.png')
plt.imshow(img)
plt.show()

# %% [markdown]
# # **Load Data**

# %%
df_train = pd.read_csv('/content/drive/MyDrive/sign_mnist_train.csv')
df_train.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      3     107     118     127     134     139     143     146     150
# 1      6     155     157     156     156     156     157     156     158
# 2      2     187     188     188     187     187     186     187     188
# 3      2     211     211     212     212     211     210     211     210
# 4     13     164     167     170     172     176     179     180     184
#
#    pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0     153  ...       207       207       207       207       206       206
# 1     158  ...        69       149       128        87        94       163
# 2     187  ...       202       201       200       199       198       199
# 3     210  ...       235       234       233       231       230       226
# 4     185  ...        92       105       105       108       133       163
#
#    pixel781  pixel782  pixel783  pixel784
# 0       206       204       203       202
# 1       175       103       135       149
# 2       198       195       194       195
# 3       225       222       229       163
# 4       157       163       164       179
#
# [5 rows x 785 columns]

# %%
df_train.describe()
# Out:
#               label        pixel1        pixel2        pixel3        pixel4  \
# count  27455.000000  27455.000000  27455.000000  27455.000000  27455.000000
# mean      12.318813    145.419377    148.500273    151.247714    153.546531
# std        7.287552     41.358555     39.942152     39.056286     38.595247
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        6.000000    121.000000    126.000000    130.000000    133.000000
# 50%       13.000000    150.000000    153.000000    156.000000    158.000000
# 75%       19.000000    174.000000    176.000000    178.000000    179.000000
# max       24.000000    255.000000    255.000000    255.000000    255.000000
#
#              pixel5        pixel6        pixel7        pixel8        pixel9  \
# count  27455.000000  27455.000000  27455.000000  27455.000000  27455.000000
# mean     156.210891    158.411255    160.472154    162.339683    163.954799
# std       37.111165     36.125579     35.016392     33.661998     32.651607
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      137.000000    140.000000    142.000000    144.000000    146.000000
# 50%      160.000000    162.000000    164.000000    165.000000    166.000000
# 75%      181.000000    182.000000    183.000000    184.000000    185.000000
# max      255.000000    255.000000    255.000000    255.000000    255.000000
#
#        ...      pixel775      pixel776      pixel777      pixel778  \
# count  ...  27455.000000  27455.000000  27455.000000  27455.000000
# mean   ...    141.104863    147.495611    153.325806    159.125332
# std    ...     63.751194     65.512894     64.427412     63.708507
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...     92.000000     96.000000    103.000000    112.000000
# 50%    ...    144.000000    162.000000    172.000000    180.000000
# 75%    ...    196.000000    202.000000    205.000000    207.000000
# max    ...    255.000000    255.000000    255.000000    255.000000
#
#            pixel779      pixel780      pixel781      pixel782      pixel783  \
# count  27455.000000  27455.000000  27455.000000  27455.000000  27455.000000
# mean     161.969259    162.736696    162.906137    161.966454    161.137898
# std       63.738316     63.444008     63.509210     63.298721     63.610415
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%      120.000000    125.000000    128.000000    128.000000    128.000000
# 50%      183.000000    184.000000    184.000000    182.000000    182.000000
# 75%      208.000000    207.000000    207.000000    206.000000    204.000000
# max      255.000000    255.000000    255.000000    255.000000    255.000000
#
#            pixel784
# count  27455.000000
# mean     159.824731
# std       64.396846
# min        0.000000
# 25%      125.500000
# 50%      182.000000
# 75%      204.000000
# max      255.000000
#
# [8 rows x 785 columns]

# %%
df_train.shape
# Out:
# (27455, 785)

# %%
df_test = pd.read_csv('/content/drive/MyDrive/sign_mnist_test.csv')
df_test.head()
# Out:
#    label  pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  \
# 0      6     149     149     150     150     150     151     151     150
# 1      5     126     128     131     132     133     134     135     135
# 2     10      85      88      92      96     105     123     135     143
# 3      0     203     205     207     206     207     209     210     209
# 4      3     188     191     193     195     199     201     202     203
#
#    pixel9  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0     151  ...       138       148       127        89        82        96
# 1     136  ...        47       104       194       183       186       184
# 2     147  ...        68       166       242       227       230       227
# 3     210  ...       154       248       247       248       253       236
# 4     203  ...        26        40        64        48        29        46
#
#    pixel781  pixel782  pixel783  pixel784
# 0       106       112       120       107
# 1       184       184       182       180
# 2       226       225       224       222
# 3       230       240       253       255
# 4        49        46        46        53
#
# [5 rows x 785 columns]

# %%
df_test.shape
# Out:
# (7172, 785)

# %% [markdown]
# # **Data INFO**

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27455 entries, 0 to 27454
# Columns: 785 entries, label to pixel784
# dtypes: int64(785)
# memory usage: 164.4 MB

# %%
df_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7172 entries, 0 to 7171
# Columns: 785 entries, label to pixel784
# dtypes: int64(785)
# memory usage: 43.0 MB

# %%
plt.style.use("ggplot")
plt.figure(figsize =(9,5))
sns.countplot(x= df_train['label'],data = df_train)
plt.show()

# %%
y_train = df_train['label']
df_train.drop(['label'], axis=1, inplace=True)
df_train.head()
# Out:
#    pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  pixel9  \
# 0     107     118     127     134     139     143     146     150     153
# 1     155     157     156     156     156     157     156     158     158
# 2     187     188     188     187     187     186     187     188     187
# 3     211     211     212     212     211     210     211     210     210
# 4     164     167     170     172     176     179     180     184     185
#
#    pixel10  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0      156  ...       207       207       207       207       206       206
# 1      157  ...        69       149       128        87        94       163
# 2      186  ...       202       201       200       199       198       199
# 3      211  ...       235       234       233       231       230       226
# 4      186  ...        92       105       105       108       133       163
#
#    pixel781  pixel782  pixel783  pixel784
# 0       206       204       203       202
# 1       175       103       135       149
# 2       198       195       194       195
# 3       225       222       229       163
# 4       157       163       164       179
#
# [5 rows x 784 columns]

# %%
y_test = df_test['label']
df_test.drop(['label'], axis=1, inplace=True)
df_test.head()
# Out:
#    pixel1  pixel2  pixel3  pixel4  pixel5  pixel6  pixel7  pixel8  pixel9  \
# 0     149     149     150     150     150     151     151     150     151
# 1     126     128     131     132     133     134     135     135     136
# 2      85      88      92      96     105     123     135     143     147
# 3     203     205     207     206     207     209     210     209     210
# 4     188     191     193     195     199     201     202     203     203
#
#    pixel10  ...  pixel775  pixel776  pixel777  pixel778  pixel779  pixel780  \
# 0      152  ...       138       148       127        89        82        96
# 1      138  ...        47       104       194       183       186       184
# 2      152  ...        68       166       242       227       230       227
# 3      209  ...       154       248       247       248       253       236
# 4      203  ...        26        40        64        48        29        46
#
#    pixel781  pixel782  pixel783  pixel784
# 0       106       112       120       107
# 1       184       184       182       180
# 2       226       225       224       222
# 3       230       240       253       255
# 4        49        46        46        53
#
# [5 rows x 784 columns]

# %%
size  = 28
channels = 1
batch = 128
epochs = 100

X_train = df_train.values.reshape(df_train.shape[0], size, size, channels)
X_test = df_test.values.reshape(df_test.shape[0], size, size, channels)

print("X_train shape:", X_train.shape)
print("X_test shape:", X_test.shape)
# Out:
# X_train shape: (27455, 28, 28, 1)
# X_test shape: (7172, 28, 28, 1)

# %% [markdown]
# # **Data augmentation and Normalization**

# %%
datagen = ImageDataGenerator(rescale=1./255,
                             zoom_range=0.2,
                             width_shift_range=.2, height_shift_range=.2,
                             rotation_range=30,
                             brightness_range=[0.8, 1.2],
                             horizontal_flip=True)

datagenRescale = ImageDataGenerator(rescale=1./255)

X_train = datagen.flow(X_train, y_train, batch_size=batch)

X_test = datagenRescale.flow(X_test, y_test)

# %% [markdown]
# # **Models Performance**

# %%
alphabet = "ABCDEFGHIJKLMNOPQRSTUVWXYZ"
plt.figure(figsize=(10, 6))
for i in range(9):
    plt.subplot(2, 5, i+1)
    for X_batch, Y_batch in X_train:
        image = X_batch[i]
        plt.imshow(image, cmap='gray')
        plt.xlabel(alphabet[Y_batch[i]])
        break
plt.tight_layout()
plt.show()

# %% [markdown]
# # **Build DCNN Model**

# %%
checkpoint_filepath = 'Sign_Language_Model.h5'

callback_checkpoint = ModelCheckpoint(filepath=checkpoint_filepath, save_weights_only=False, monitor='val_accuracy', mode='max', save_best_only=True)
callback_learningrate = ReduceLROnPlateau(monitor='loss', mode='min', min_delta=0.01, patience=3, factor=.75, min_lr=0.00001, verbose=1)

callbacks = [callback_checkpoint, callback_learningrate]

# %%
Model = Sequential([Conv2D(filters=32,  kernel_size=(3,3), activation="relu", input_shape=(size,size,channels)),
                    MaxPool2D(2,2, padding='same'),
                    Dropout(0.2),
                 
                    Conv2D(filters=128,  kernel_size=(3,3), activation="relu"),
                    MaxPool2D(2,2, padding='same'),
                    Dropout(0.2),
                
                    Conv2D(filters=512, kernel_size=(3,3), activation="relu"),
                    MaxPool2D(2,2, padding='same'),
                    Dropout(0.2),
                    
                    
                    Flatten(),
                    
                    Dense(units=4096, activation="relu"),                 
                    Dropout(0.2),
                    
                    Dense(units=1024, activation="relu"),
                    Dropout(0.2),
                                  
                    Dense(units=256, activation="relu"),
                    Dropout(0.2),
                    
                    Dense(units=25, activation="softmax"),
])


Model.compile(optimizer='adam', loss="sparse_categorical_crossentropy", metrics=["accuracy"])


Model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d_3 (Conv2D)           (None, 26, 26, 32)        320
#
#  max_pooling2d_3 (MaxPooling  (None, 13, 13, 32)       0
#  2D)
#
#  dropout_6 (Dropout)         (None, 13, 13, 32)        0
#
#  conv2d_4 (Conv2D)           (None, 11, 11, 128)       36992
#
#  max_pooling2d_4 (MaxPooling  (None, 6, 6, 128)        0
#  2D)
#
#  dropout_7 (Dropout)         (None, 6, 6, 128)         0
#
#  conv2d_5 (Conv2D)           (None, 4, 4, 512)         590336
#
#  max_pooling2d_5 (MaxPooling  (None, 2, 2, 512)        0
#  2D)
#
#  dropout_8 (Dropout)         (None, 2, 2, 512)         0
#
#  flatten_1 (Flatten)         (None, 2048)              0
#
#  dense_4 (Dense)             (None, 4096)              8392704
#
#  dropout_9 (Dropout)         (None, 4096)              0
#
#  dense_5 (Dense)             (None, 1024)              4195328
#
#  dropout_10 (Dropout)        (None, 1024)              0
#
#  dense_6 (Dense)             (None, 256)               262400
#
#  dropout_11 (Dropout)        (None, 256)               0
#
#  dense_7 (Dense)             (None, 25)                6425
#
# =================================================================
# Total params: 13,484,505
# Trainable params: 13,484,505
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# # **Train Model**

# %%
history = Model.fit(X_train, validation_data=X_test, epochs=epochs, callbacks=callbacks)
# Out:
# Epoch 1/100
# 215/215 [==============================] - 21s 86ms/step - loss: 3.1049 - accuracy: 0.0639 - val_loss: 2.8670 - val_accuracy: 0.0958 - lr: 0.0010
# Epoch 2/100
# 215/215 [==============================] - 17s 81ms/step - loss: 2.5188 - accuracy: 0.1842 - val_loss: 1.8373 - val_accuracy: 0.3394 - lr: 0.0010
# Epoch 3/100
# 215/215 [==============================] - 18s 84ms/step - loss: 1.7384 - accuracy: 0.3939 - val_loss: 1.1439 - val_accuracy: 0.5414 - lr: 0.0010
# Epoch 4/100
# 215/215 [==============================] - 18s 83ms/step - loss: 1.2559 - accuracy: 0.5615 - val_loss: 0.7029 - val_accuracy: 0.7038 - lr: 0.0010
# Epoch 5/100
# 215/215 [==============================] - 17s 81ms/step - loss: 0.9984 - accuracy: 0.6516 - val_loss: 0.5408 - val_accuracy: 0.8302 - lr: 0.0010
# Epoch 6/100
# 215/215 [==============================] - 18s 81ms/step - loss: 0.8336 - accuracy: 0.7066 - val_loss: 0.3948 - val_accuracy: 0.8434 - lr: 0.0010
# Epoch 7/100
# 215/215 [==============================] - 19s 86ms/step - loss: 0.7257 - accuracy: 0.7464 - val_loss: 0.2495 - val_accuracy: 0.9018 - lr: 0.0010
# Epoch 8/100
# 215/215 [==============================] - 17s 80ms/step - loss: 0.6366 - accuracy: 0.7792 - val_loss: 0.2276 - val_accuracy: 0.9056 - lr: 0.0010
# Epoch 9/100
# 215/215 [==============================] - 18s 82ms/step - loss: 0.5714 - accuracy: 0.8056 - val_loss: 0.1487 - val_accuracy: 0.9340 - lr: 0.0010
# Epoch 10/100
# 215/215 [==============================] - 19s 87ms/step - loss: 0.5202 - accuracy: 0.8222 - val_loss: 0.0983 - val_accuracy: 0.9611 - lr: 0.0010
100
# 215/215 [==============================] - ETA: 0s - loss: 0.0739 - accuracy: 0.9757
# Epoch 77: ReduceLROnPlateau reducing learning rate to 4.223513315082528e-05.
# 215/215 [==============================] - 17s 80ms/step - loss: 0.0739 - accuracy: 0.9757 - val_loss: 4.4136e-04 - val_accuracy: 1.0000 - lr: 5.6314e-05
# Epoch 78/100
# 215/215 [==============================] - 18s 85ms/step - loss: 0.0739 - accuracy: 0.9748 - val_loss: 5.7999e-04 - val_accuracy: 1.0000 - lr: 4.2235e-05
# Epoch 79/100
# 215/215 [==============================] - 17s 79ms/step - loss: 0.0694 - accuracy: 0.9768 - val_loss: 5.7778e-04 - val_accuracy: 1.0000 - lr: 4.2235e-05
# Epoch 80/100
# 215/215 [==============================] - 17s 81ms/step - loss: 0.0735 - accuracy: 0.9755 - val_loss: 9.6104e-04 - val_accuracy: 1.0000 - lr: 4.2235e-05
# Epoch 81/100
# 215/215 [==============================] - 19s 87ms/step - loss: 0.0704 - accuracy: 0.9764 - val_loss: 3.8740e-04 - val_accuracy: 1.0000 - lr: 4.2235e-05
# Epoch 82/100
# 215/215 [==============================] - ETA: 0s - loss: 0.0693 - accuracy: 0.9779
# Epoch 82: ReduceLROnPlateau reducing learning rate to 3.167634986311896e-05.
# 215/215 [==============================] - 17s 79ms/step - loss: 0.0693 - accuracy: 0.9779 - val_loss: 4.9268e-04 - val_accuracy: 1.0000 - lr: 4.2235e-05
# Epoch 83/100
# 215/215 [==============================] - 17s 81ms/step - loss: 0.0707 - accuracy: 0.9759 - val_loss: 5.1845e-04 - val_accuracy: 1.0000 - lr: 3.1676e-05
# Epoch 84/100
# 215/215 [==============================] - 18s 84ms/step - loss: 0.0654 - accuracy: 0.9781 - val_loss: 3.6572e-04 - val_accuracy: 1.0000 - lr: 3.1676e-05
# Epoch 85/100
# 215/215 [==============================] - ETA: 0s - loss: 0.0695 - accuracy: 0.9776
# Epoch 85: ReduceLROnPlateau reducing learning rate to 2.3757263079460245e-05.
# 215/215 [==============================] - 18s 84ms/step - loss: 0.0695 - accuracy: 0.9776 - val_loss: 4.1915e-04 - val_accuracy: 1.0000 - lr: 3.1676e-05
# Epoch 86/100
# 215/215 [==============================] - 17s 81ms/step - loss: 0.0686 - accuracy: 0.9786 - val_loss: 4.4717e-04 - val_accuracy: 1.0000 - lr: 2.3757e-05
# Epoch 87/100
# 215/215 [==============================] - 18s 84ms/step - loss: 0.0743 - accuracy: 0.9759 - val_loss: 3.8969e-04 - val_accuracy: 1.0000 - lr: 2.3757e-05
# Epoch 88/100
# 215/215 [==============================] - ETA: 0s - loss: 0.0636 - accuracy: 0.9782
# Epoch 88: ReduceLROnPlateau reducing learning rate to 1.781794799171621e-05.
# 215/215 [==============================] - 17s 81ms/step - loss: 0.0636 - accuracy: 0.9782 - val_loss: 3.6037e-04 - val_accuracy: 1.0000 - lr: 2.3757e-05
# Epoch 89/100
# 215/215 [==============================] - 17s 80ms/step - loss: 0.0693 - accuracy: 0.9761 - val_loss: 3.1458e-04 - val_accuracy: 1.0000 - lr: 1.7818e-05
# Epoch 90/100
# 215/215 [==============================] - 18s 82ms/step - loss: 0.0705 - accuracy: 0.9769 - val_loss: 3.7911e-04 - val_accuracy: 1.0000 - lr: 1.7818e-05
# Epoch 91/100
# 215/215 [==============================] - ETA: 0s - loss: 0.0672 - accuracy: 0.9777
# Epoch 91: ReduceLROnPlateau reducing learning rate to 1.3363460311666131e-05.
# 215/215 [==============================] - 18s 82ms/step - loss: 0.0672 - accuracy: 0.9777 - val_loss: 3.9770e-04 - val_accuracy: 1.0000 - lr: 1.7818e-05
# Epoch 92/100
# 215/215 [==============================] - 18s 85ms/step - loss: 0.0705 - accuracy: 0.9764 - val_loss: 3.5350e-04 - val_accuracy: 1.0000 - lr: 1.3363e-05
# Epoch 93/100
# 215/215 [==============================] - 18s 82ms/step - loss: 0.0665 - accuracy: 0.9776 - val_loss: 4.0138e-04 - val_accuracy: 1.0000 - lr: 1.3363e-05
# Epoch 94/100
# 215/215 [==============================] - ETA: 0s - loss: 0.0718 - accuracy: 0.9772
# Epoch 94: ReduceLROnPlateau reducing learning rate to 1.0022595233749598e-05.
# 215/215 [==============================] - 18s 82ms/step - loss: 0.0718 - accuracy: 0.9772 - val_loss: 3.8839e-04 - val_accuracy: 1.0000 - lr: 1.3363e-05
# Epoch 95/100
# 215/215 [==============================] - 18s 85ms/step - loss: 0.0684 - accuracy: 0.9772 - val_loss: 3.5635e-04 - val_accuracy: 1.0000 - lr: 1.0023e-05
# Epoch 96/100
# 215/215 [==============================] - 18s 82ms/step - loss: 0.0712 - accuracy: 0.9781 - val_loss: 4.1983e-04 - val_accuracy: 1.0000 - lr: 1.0023e-05
# Epoch 97/100
# 215/215 [==============================] - ETA: 0s - loss: 0.0682 - accuracy: 0.9774
# Epoch 97: ReduceLROnPlateau reducing learning rate to 1e-05.
# 215/215 [==============================] - 17s 81ms/step - loss: 0.0682 - accuracy: 0.9774 - val_loss: 3.6561e-04 - val_accuracy: 1.0000 - lr: 1.0023e-05
# Epoch 98/100
# 215/215 [==============================] - 19s 86ms/step - loss: 0.0660 - accuracy: 0.9788 - val_loss: 3.6529e-04 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 99/100
# 215/215 [==============================] - 17s 81ms/step - loss: 0.0640 - accuracy: 0.9785 - val_loss: 4.2069e-04 - val_accuracy: 1.0000 - lr: 1.0000e-05
# Epoch 100/100
# 215/215 [==============================] - 18s 83ms/step - loss: 0.0680 - accuracy: 0.9769 - val_loss: 3.8463e-04 - val_accuracy: 1.0000 - lr: 1.0000e-05

# %% [markdown]
# # **Train Curves**

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(len(acc))

plt.figure(figsize=(10, 10))
plt.subplot(2, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(2, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# # **Test Model**

# %%
df_test = pd.read_csv('/content/drive/MyDrive/sign_mnist_test.csv')
y_test = df_test['label']
df_test.drop(['label'], axis=1, inplace=True)
X_test = df_test.values.reshape(df_test.shape[0], size, size, channels)

# %%
y_pred = np.argmax(Model.predict(X_test),axis = 1)
# Out:
# 225/225 [==============================] - 1s 2ms/step

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test,y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      1.00      0.99       331
#            1       1.00      1.00      1.00       432
#            2       1.00      0.91      0.95       310
#            3       1.00      1.00      1.00       245
#            4       1.00      1.00      1.00       498
#            5       0.96      1.00      0.98       247
#            6       0.89      0.96      0.92       348
#            7       0.98      0.90      0.94       436
#            8       1.00      1.00      1.00       288
#           10       1.00      1.00      1.00       331
#           11       1.00      1.00      1.00       209
#           12       1.00      1.00      1.00       394
#           13       1.00      0.98      0.99       291
#           14       0.89      1.00      0.94       246
#           15       1.00      1.00      1.00       347
#           16       0.98      1.00      0.99       164
#           17       1.00      0.99      0.99       144
#           18       0.99      1.00      1.00       246
#           19       0.99      1.00      0.99       248
#           20       1.00      1.00      1.00       266
#           21       1.00      0.88      0.94       346
#           22       0.87      1.00      0.93       206
#           23       1.00      1.00      1.00       267
#           24       1.00      1.00      1.00       332
#
#     accuracy                           0.98      7172
#    macro avg       0.98      0.98      0.98      7172
# weighted avg       0.98      0.98      0.98      7172

# %%
plt.figure(figsize=(10,10))
for i in range(9):
    plt.subplot(3,3,i+1)
    plt.imshow(X_test[i],cmap='gray')
    plt.ylabel(f"True: {alphabet[y_test[i]]}")
    plt.xlabel(f"Predicted: {alphabet[y_pred[i]]}")
    
plt.show()
